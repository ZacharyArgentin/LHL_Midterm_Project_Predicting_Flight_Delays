# %% [markdown]
# # Cleaning Data for the random sample dataset

# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("data/flights_random_sample_400000.csv")

# %%
df.head()
# Out:
#       fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0  2018-03-07                 AA                 AA          AA
# 1  2018-03-07                 AA                 AA          AA
# 2  2018-03-07                 AA                 AA          AA
# 3  2018-03-07                 AA                 AA          AA
# 4  2018-03-07                 AA                 AA          AA
#
#    mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                 311                AA   N906NN                311
# 1                 332                AA   N946NN                332
# 2                 465                AA   N200UU                465
# 3                 550                AA   N947UW                550
# 4                 591                AA   N833AW                591
#
#    origin_airport_id origin  origin_city_name  dest_airport_id dest  \
# 0              13303    MIA         Miami, FL            10529  BDL
# 1              12953    LGA      New York, NY            13930  ORD
# 2              14107    PHX       Phoenix, AZ            14679  SAN
# 3              14100    PHL  Philadelphia, PA            10529  BDL
# 4              11057    CLT     Charlotte, NC            11278  DCA
#
#    dest_city_name  crs_dep_time  dep_time  dep_delay  taxi_out  wheels_off  \
# 0    Hartford, CT          1940       NaN        NaN       NaN         NaN
# 1     Chicago, IL          1330       NaN        NaN       NaN         NaN
# 2   San Diego, CA           835     833.0       -2.0      13.0       846.0
# 3    Hartford, CT          2050       NaN        NaN       NaN         NaN
# 4  Washington, DC          1431    1537.0       66.0      16.0      1553.0
#
#    wheels_on  taxi_in  crs_arr_time  arr_time  arr_delay  cancelled  \
# 0        NaN      NaN          2249       NaN        NaN        1.0
# 1        NaN      NaN          1512       NaN        NaN        1.0
# 2      838.0      2.0           851     840.0      -11.0        0.0
# 3        NaN      NaN          2156       NaN        NaN        1.0
# 4     1648.0      3.0          1559    1651.0       52.0        0.0
#
#   cancellation_code  diverted dup  crs_elapsed_time  actual_elapsed_time  \
# 0                 B       0.0   N             189.0                  NaN
# 1                 B       0.0   N             162.0                  NaN
# 2               NaN       0.0   N              76.0                 67.0
# 3                 B       0.0   N              66.0                  NaN
# 4               NaN       0.0   N              88.0                 74.0
#
#    air_time  flights  distance  carrier_delay  weather_delay  nas_delay  \
# 0       NaN      1.0    1194.0            NaN            NaN        NaN
# 1       NaN      1.0     733.0            NaN            NaN        NaN
# 2      52.0      1.0     304.0            NaN            NaN        NaN
# 3       NaN      1.0     196.0            NaN            NaN        NaN
# 4      55.0      1.0     331.0           52.0            0.0        0.0
#
#    security_delay  late_aircraft_delay  first_dep_time  total_add_gtime  \
# 0             NaN                  NaN             NaN              NaN
# 1             NaN                  NaN             NaN              NaN
# 2             NaN                  NaN             NaN              NaN
# 3             NaN                  NaN             NaN              NaN
# 4             0.0                  0.0             NaN              NaN
#
#    longest_add_gtime  no_name
# 0                NaN      NaN
# 1                NaN      NaN
# 2                NaN      NaN
# 3                NaN      NaN
# 4                NaN      NaN

# %% [markdown]
# ### Fixing null values and dropping redundant/irrelevant columns

# %%
# mkt_carrier is the same as mke_unique_carrier
df = df.drop(["mkt_unique_carrier"], axis=1)

# %%
# Drop rows that don't have an arrival time (can't predict arr_delay if play never arrived)
df = df.dropna(subset=["arr_time"])

# %%
# drop flights that were diverted (they don't have an arr_time)
df = df[df["diverted"].ne(1)]

# %%
# The remaining flights with null values in arr_delay have the same predicted arrival time as actual arrival time
df["arr_delay"].fillna(0, inplace=True)

# %%
# The remaining flights with null values in dep_delay have the same predicted departure time as actual departure time
df["dep_delay"].fillna(0, inplace=True)

# %%
# drop flights that weren't actually flights??? These all seem to be codeshares from hawaiian airlines.
df = df.dropna(subset=["air_time"])

# %%
# Our dataframe no longer has any cancelled flights in it
df = df.drop(["cancelled", "cancellation_code"], axis=1)

# %%
# no_name is an empty column
df = df.drop(["no_name"], axis=1)

# %%
# create dataframe for delay details (may or may not need this later. probably not)
delay_details_cols = list(df.columns[-8:])
df_delay_details = df[delay_details_cols]
df_delay_details.head()

# %%
# drop delay details columns
df = df.drop(delay_details_cols, axis=1)

# %%
# dataframe no longer contains any flights that were diverted
df = df.drop(["diverted"], axis=1)

# %%
# no unique values in this column (all "N")
df = df.drop(["dup"], axis=1)

# %%
# no unique values in this column (all "1")
df = df.drop(["flights"], axis=1)

# %%
df.head()
# Out:
#       fl_date branded_code_share mkt_carrier  mkt_carrier_fl_num  \
# 2  2018-03-07                 AA          AA                 465
# 4  2018-03-07                 AA          AA                 591
# 5  2018-03-07                 AA          AA                 600
# 6  2018-03-07                 AA          AA                1805
# 7  2018-03-07                 AA          AA                2615
#
#   op_unique_carrier tail_num  op_carrier_fl_num  origin_airport_id origin  \
# 2                AA   N200UU                465              14107    PHX
# 4                AA   N833AW                591              11057    CLT
# 5                AA   N151UW                600              11697    FLL
# 6                AA   N924US               1805              11057    CLT
# 7                AA   N945NN               2615              11057    CLT
#
#       origin_city_name  dest_airport_id dest  dest_city_name  crs_dep_time  \
# 2          Phoenix, AZ            14679  SAN   San Diego, CA           835
# 4        Charlotte, NC            11278  DCA  Washington, DC          1431
# 5  Fort Lauderdale, FL            11057  CLT   Charlotte, NC           603
# 6        Charlotte, NC            10721  BOS      Boston, MA          1135
# 7        Charlotte, NC            15370  TUL       Tulsa, OK          1820
#
#    dep_time  dep_delay  taxi_out  wheels_off  wheels_on  taxi_in  \
# 2     833.0       -2.0      13.0       846.0      838.0      2.0
# 4    1537.0       66.0      16.0      1553.0     1648.0      3.0
# 5     557.0       -6.0      18.0       615.0      746.0     19.0
# 6    1129.0       -6.0      11.0      1140.0     1312.0     12.0
# 7    1812.0       -8.0      11.0      1823.0     1936.0      6.0
#
#    crs_arr_time  arr_time  arr_delay  crs_elapsed_time  actual_elapsed_time  \
# 2           851     840.0      -11.0              76.0                 67.0
# 4          1559    1651.0       52.0              88.0                 74.0
# 5           809     805.0       -4.0             126.0                128.0
# 6          1352    1324.0      -28.0             137.0                115.0
# 7          2002    1942.0      -20.0             162.0                150.0
#
#    air_time  distance
# 2      52.0     304.0
# 4      55.0     331.0
# 5      91.0     632.0
# 6      92.0     728.0
# 7     133.0     842.0

# %%
df.shape
# Out:
# (390060, 29)

# %%
df.isnull().sum()
# Out:
# fl_date                0
# branded_code_share     0
# mkt_carrier            0
# mkt_carrier_fl_num     0
# op_unique_carrier      0
# tail_num               0
# op_carrier_fl_num      0
# origin_airport_id      0
# origin                 0
# origin_city_name       0
# dest_airport_id        0
# dest                   0
# dest_city_name         0
# crs_dep_time           0
# dep_time               0
# dep_delay              0
# taxi_out               0
# wheels_off             0
# wheels_on              0
# taxi_in                0
# crs_arr_time           0
# arr_time               0
# arr_delay              0
# dup                    0
# crs_elapsed_time       0
# actual_elapsed_time    0
# air_time               0
# flights                0
# distance               0
# dtype: int64

# %% [markdown]
# ### further analysis of outliers / incorrect data

# %%
df.describe()
# Out:
#        mkt_carrier_fl_num  op_carrier_fl_num  origin_airport_id  \
# count       390058.000000      390058.000000      390058.000000
# mean          2718.410926        2718.345302       12676.967948
# std           1859.335215        1859.396220        1526.030261
# min              1.000000           1.000000       10135.000000
# 25%           1118.000000        1118.000000       11292.000000
# 50%           2297.000000        2297.000000       12889.000000
# 75%           4295.000000        4294.000000       14057.000000
# max           9392.000000        9392.000000       16869.000000
#
#        dest_airport_id   crs_dep_time       dep_time      dep_delay  \
# count    390058.000000  390058.000000  390058.000000  390058.000000
# mean      12681.838778    1328.864210    1333.971335      10.491965
# std        1522.948134     490.482159     504.579315      47.911094
# min       10135.000000       1.000000       1.000000     -45.000000
# 25%       11292.000000     914.000000     915.000000      -6.000000
# 50%       12889.000000    1320.000000    1327.000000      -2.000000
# 75%       14057.000000    1735.000000    1744.000000       7.000000
# max       16869.000000    2359.000000    2400.000000    1855.000000
#
#             taxi_out     wheels_off      wheels_on        taxi_in  \
# count  390058.000000  390058.000000  390058.000000  390058.000000
# mean       17.511406    1358.154159    1458.801278       7.684683
# std        10.036387     506.093594     532.940981       6.134376
# min         0.000000       1.000000       1.000000       0.000000
# 25%        11.000000     931.000000    1043.000000       4.000000
# 50%        15.000000    1340.000000    1458.000000       6.000000
# 75%        20.000000    1800.000000    1909.000000       9.000000
# max       165.000000    2400.000000    2400.000000     221.000000
#
#         crs_arr_time       arr_time      arr_delay  crs_elapsed_time  \
# count  390058.000000  390058.000000  390058.000000     390058.000000
# mean     1482.925544    1463.658176       5.499105        138.100862
# std       517.171786     537.038187      50.114987         71.878009
# min         1.000000       1.000000     -85.000000         20.000000
# 25%      1100.000000    1048.000000     -15.000000         87.000000
# 50%      1510.000000    1502.000000      -6.000000        119.000000
# 75%      1916.000000    1914.000000       8.000000        168.000000
# max      2400.000000    2400.000000    1863.000000        703.000000
#
#        actual_elapsed_time       air_time       distance
# count        390058.000000  390058.000000  390058.000000
# mean            133.113665     107.917576     770.283576
# std              71.718236      69.804743     587.824801
# min              16.000000       8.000000      31.000000
# 25%              82.000000      58.000000     341.000000
# 50%             114.000000      89.000000     604.000000
# 75%             163.000000     137.000000    1005.000000
# max             715.000000     688.000000    5095.000000

# %%
# Drop flights that had a negative elapsed time for some reason
df = df[df["crs_elapsed_time"].gt(0)]

# %%
# fixing a single flight value
df.loc[326616, "crs_elapsed_time"] = 89.0
# Out:
# /Users/zacharyargentin/opt/anaconda3/envs/bootcamp/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.sort_values("taxi_in").tail(10)
# Out:
#            fl_date branded_code_share mkt_carrier  mkt_carrier_fl_num  \
# 311669  2019-07-31                 DL          DL                2915
# 313654  2018-01-05                 DL          DL                 984
# 240341  2018-07-27                 DL          DL                1669
# 369409  2018-11-15                 DL          DL                1841
# 336655  2018-08-18                 AA          AA                2720
# 18137   2019-08-08                 DL          DL                2629
# 240169  2018-07-27                 NK          NK                 423
# 336797  2018-08-18                 AA          AA                2372
# 336625  2018-08-18                 AA          AA                1399
# 233560  2018-07-16       DL_CODESHARE          DL                3322
#
#        op_unique_carrier tail_num  op_carrier_fl_num  origin_airport_id  \
# 311669                DL   N184DN               2915              14869
# 313654                DL   N352NW                984              10397
# 240341                DL   N6715C               1669              10397
# 369409                DL   N834MH               1841              12892
# 336655                AA   N4005X               2720              15919
# 18137                 DL   N321DH               2629              10397
# 240169                NK   N623NK                423              10721
# 336797                AA   N163AA               2372              14683
# 336625                AA   N955NN               1399              12892
# 233560                9E   N197PQ               3322              10397
#
#        origin    origin_city_name  dest_airport_id dest  \
# 311669    SLC  Salt Lake City, UT            10721  BOS
# 313654    ATL         Atlanta, GA            12478  JFK
# 240341    ATL         Atlanta, GA            13204  MCO
# 369409    LAX     Los Angeles, CA            12478  JFK
# 336655    XNA    Fayetteville, AR            11298  DFW
# 18137     ATL         Atlanta, GA            12953  LGA
# 240169    BOS          Boston, MA            13204  MCO
# 336797    SAT     San Antonio, TX            11298  DFW
# 336625    LAX     Los Angeles, CA            11298  DFW
# 233560    ATL         Atlanta, GA            11973  GPT
#
#                dest_city_name  crs_dep_time  dep_time  dep_delay  taxi_out  \
# 311669             Boston, MA           935     933.0       -2.0      20.0
# 313654           New York, NY          2142    2158.0       16.0       8.0
# 240341            Orlando, FL          1815    1828.0       13.0      17.0
# 369409           New York, NY          1420    1419.0       -1.0      26.0
# 336655  Dallas/Fort Worth, TX          1816    2014.0      118.0     136.0
# 18137            New York, NY          1430    1543.0       73.0      24.0
# 240169            Orlando, FL          1550    1605.0       15.0      14.0
# 336797  Dallas/Fort Worth, TX          1950    2027.0       37.0     134.0
# 336625  Dallas/Fort Worth, TX          1820    1819.0       -1.0      22.0
# 233560    Gulfport/Biloxi, MS          1247    1301.0       14.0      18.0
#
#         wheels_off  wheels_on  taxi_in  crs_arr_time  arr_time  arr_delay  \
# 311669       953.0     1705.0    151.0          1626    1936.0      190.0
# 313654      2206.0     2344.0    151.0             5     215.0      130.0
# 240341      1845.0     1941.0    157.0          2000    2218.0      138.0
# 369409      1445.0     2235.0    165.0          2251     120.0      149.0
# 336655      2230.0     2314.0    169.0          1942     203.0      381.0
# 18137       1607.0     1757.0    171.0          1645    2048.0      243.0
# 240169      1619.0     1929.0    171.0          1910    2220.0      190.0
# 336797      2241.0     2325.0    172.0          2104     217.0      313.0
# 336625      1841.0     2316.0    176.0          2330     212.0      162.0
# 233560      1319.0     1317.0    221.0          1312    1658.0      226.0
#
#         crs_elapsed_time  actual_elapsed_time  air_time  distance
# 311669             291.0                483.0     312.0    2105.0
# 313654             143.0                257.0      98.0     760.0
# 240341             105.0                230.0      56.0     404.0
# 369409             331.0                481.0     290.0    2475.0
# 336655              86.0                349.0      44.0     280.0
# 18137              135.0                305.0     110.0     762.0
# 240169             200.0                375.0     190.0    1121.0
# 336797              74.0                350.0      44.0     247.0
# 336625             190.0                353.0     155.0    1235.0
# 233560              85.0                297.0      58.0     352.0

# %% [markdown]
# ### dtypes

# %%
df2 = df.copy()

# %%
df2.dtypes
# Out:
# fl_date                 object
# branded_code_share      object
# mkt_carrier             object
# mkt_carrier_fl_num       int64
# op_unique_carrier       object
# tail_num                object
# op_carrier_fl_num        int64
# origin_airport_id        int64
# origin                  object
# origin_city_name        object
# dest_airport_id          int64
# dest                    object
# dest_city_name          object
# crs_dep_time             int64
# dep_time               float64
# dep_delay              float64
# taxi_out               float64
# wheels_off             float64
# wheels_on              float64
# taxi_in                float64
# crs_arr_time             int64
# arr_time               float64
# arr_delay              float64
# crs_elapsed_time       float64
# actual_elapsed_time    float64
# air_time               float64
# distance               float64
# dtype: object

# %%
help(df2.astype)
# Out:
# Help on method astype in module pandas.core.generic:
#
# astype(dtype, copy: 'bool_t' = True, errors: 'str' = 'raise') -> 'FrameOrSeries' method of pandas.core.frame.DataFrame instance
#     Cast a pandas object to a specified dtype ``dtype``.
#
#     Parameters
#     ----------
#     dtype : data type, or dict of column name -> data type
#         Use a numpy.dtype or Python type to cast entire pandas object to
#         the same type. Alternatively, use {col: dtype, ...}, where col is a
#         column label and dtype is a numpy.dtype or Python type to cast one
#         or more of the DataFrame's columns to column-specific types.
#     copy : bool, default True
#         Return a copy when ``copy=True`` (be very careful setting
#         ``copy=False`` as changes to values then may propagate to other
#         pandas objects).
#     errors : {'raise', 'ignore'}, default 'raise'
#         Control raising of exceptions on invalid data for provided dtype.
#
#         - ``raise`` : allow exceptions to be raised
#         - ``ignore`` : suppress exceptions. On error return original object.
#
#     Returns
#     -------
#     casted : same type as caller
#
#     See Also
#     --------
#     to_datetime : Convert argument to datetime.
#     to_timedelta : Convert argument to timedelta.
#     to_numeric : Convert argument to a numeric type.
#     numpy.ndarray.astype : Cast a numpy array to a specified type.
#
#     Notes
#     -----
#     .. deprecated:: 1.3.0
#
#         Using ``astype`` to convert from timezone-naive dtype to
#         timezone-aware dtype is deprecated and will raise in a
#         future version.  Use :meth:`Series.dt.tz_localize` instead.
#
#     Examples
#     --------
#     Create a DataFrame:
#
#     >>> d = {'col1': [1, 2], 'col2': [3, 4]}
#     >>> df = pd.DataFrame(data=d)
#     >>> df.dtypes
#     col1    int64
#     col2    int64
#     dtype: object
#
#     Cast all columns to int32:
#
#     >>> df.astype('int32').dtypes
#     col1    int32
#     col2    int32
#     dtype: object
#
#     Cast col1 to int32 using a dictionary:
#
#     >>> df.astype({'col1': 'int32'}).dtypes
#     col1    int32
#     col2    int64
#     dtype: object
#
#     Create a series:
#
#     >>> ser = pd.Series([1, 2], dtype='int32')
#     >>> ser
#     0    1
#     1    2
#     dtype: int32
#     >>> ser.astype('int64')
#     0    1
#     1    2
#     dtype: int64
#
#     Convert to categorical type:
#
#     >>> ser.astype('category')
#     0    1
#     1    2
#     dtype: category
#     Categories (2, int64): [1, 2]
#
#     Convert to ordered categorical type with custom ordering:
#
#     >>> from pandas.api.types import CategoricalDtype
#     >>> cat_dtype = CategoricalDtype(
#     ...     categories=[2, 1], ordered=True)
#     >>> ser.astype(cat_dtype)
#     0    1
#     1    2
#     dtype: category
#     Categories (2, int64): [2 < 1]
#
#     Note that using ``copy=False`` and changing data on a new
#     pandas object may propagate changes:
#
#     >>> s1 = pd.Series([1, 2])
#     >>> s2 = s1.astype('int64', copy=False)
#     >>> s2[0] = 10
#     >>> s1  # note that s1[0] has changed too
#     0    10
#     1     2
#     dtype: int64
#
#     Create a series of dates:
#
#     >>> ser_date = pd.Series(pd.date_range('20200101', periods=3))
#     >>> ser_date
#     0   2020-01-01
#     1   2020-01-02
#     2   2020-01-03
#     dtype: datetime64[ns]

# %%
# change numerical 'id' datatypes to object
df2 = df2.astype({"mkt_carrier_fl_num": "object",
            "op_carrier_fl_num": "object",
            "origin_airport_id": "object",
            "dest_airport_id": "object"})

# %%
# change object to string datastypes

# %%
df2.dtypes
# Out:
# fl_date                 object
# branded_code_share      object
# mkt_carrier             object
# mkt_carrier_fl_num      object
# op_unique_carrier       object
# tail_num                object
# op_carrier_fl_num       object
# origin_airport_id       object
# origin                  object
# origin_city_name        object
# dest_airport_id         object
# dest                    object
# dest_city_name          object
# crs_dep_time             int64
# dep_time               float64
# dep_delay              float64
# taxi_out               float64
# wheels_off             float64
# wheels_on              float64
# taxi_in                float64
# crs_arr_time             int64
# arr_time               float64
# arr_delay              float64
# crs_elapsed_time       float64
# actual_elapsed_time    float64
# air_time               float64
# distance               float64
# dtype: object
