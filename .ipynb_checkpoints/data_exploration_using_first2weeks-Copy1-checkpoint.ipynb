# %%
# import pandas
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.pipeline import make_pipeline
# %matplotlib inline

# %%
df = pd.read_csv("./data/flights_random_sample_400000.csv")

# %%
df
# Out:
#            fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0       2018-03-07                 AA                 AA          AA
# 1       2018-03-07                 AA                 AA          AA
# 2       2018-03-07                 AA                 AA          AA
# 3       2018-03-07                 AA                 AA          AA
# 4       2018-03-07                 AA                 AA          AA
# ...            ...                ...                ...         ...
# 397919  2018-03-07                 UA       UA_CODESHARE          UA
# 397920  2018-03-07                 AA       AA_CODESHARE          AA
# 397921  2018-03-07                 AA       AA_CODESHARE          AA
# 397922  2018-03-07                 AA       AA_CODESHARE          AA
# 397923  2018-03-07                 AA                 AA          AA
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                      311                AA   N906NN                311
# 1                      332                AA   N946NN                332
# 2                      465                AA   N200UU                465
# 3                      550                AA   N947UW                550
# 4                      591                AA   N833AW                591
# ...                    ...               ...      ...                ...
# 397919                6215                YV   N88335               6215
# 397920                4441                YX      NaN               4441
# 397921                4640                YX   N417YX               4640
# 397922                4734                YX   N433YX               4734
# 397923                 179                AA   N105NN                179
#
#         origin_airport_id origin  ... distance  carrier_delay weather_delay  \
# 0                   13303    MIA  ...   1194.0            NaN           NaN
# 1                   12953    LGA  ...    733.0            NaN           NaN
# 2                   14107    PHX  ...    304.0            NaN           NaN
# 3                   14100    PHL  ...    196.0            NaN           NaN
# 4                   11057    CLT  ...    331.0           52.0           0.0
# ...                   ...    ...  ...      ...            ...           ...
# 397919              14570    RNO  ...   1530.0            NaN           NaN
# 397920              14100    PHL  ...    119.0            NaN           NaN
# 397921              13303    MIA  ...    594.0            NaN           NaN
# 397922              14122    PIT  ...   1013.0            NaN           NaN
# 397923              12478    JFK  ...   2586.0            NaN           NaN
#
#        nas_delay  security_delay  late_aircraft_delay  first_dep_time  \
# 0            NaN             NaN                  NaN             NaN
# 1            NaN             NaN                  NaN             NaN
# 2            NaN             NaN                  NaN             NaN
# 3            NaN             NaN                  NaN             NaN
# 4            0.0             0.0                  0.0             NaN
# ...          ...             ...                  ...             ...
# 397919       NaN             NaN                  NaN             NaN
# 397920       NaN             NaN                  NaN             NaN
# 397921       NaN             NaN                  NaN             NaN
# 397922       NaN             NaN                  NaN             NaN
# 397923       NaN             NaN                  NaN             NaN
#
#         total_add_gtime  longest_add_gtime  no_name
# 0                   NaN                NaN      NaN
# 1                   NaN                NaN      NaN
# 2                   NaN                NaN      NaN
# 3                   NaN                NaN      NaN
# 4                   NaN                NaN      NaN
# ...                 ...                ...      ...
# 397919              NaN                NaN      NaN
# 397920              NaN                NaN      NaN
# 397921              NaN                NaN      NaN
# 397922              NaN                NaN      NaN
# 397923              NaN                NaN      NaN
#
# [397924 rows x 42 columns]

# %% [markdown]
# ### We are using a sample of the first weak of 2018 and 2019

# %%
df.fl_date.value_counts().sort_index(ascending=True)
# Out:
# 2018-01-01    434
# 2018-01-02    552
# 2018-01-03    472
# 2018-01-04    400
# 2018-01-05    510
#              ...
# 2019-12-27    519
# 2019-12-28    572
# 2019-12-29    599
# 2019-12-30    563
# 2019-12-31    468
# Name: fl_date, Length: 730, dtype: int64

# %%
df = df.dropna(subset=["arr_time"])

# %%
df = df[df["diverted"].ne(1)]

# %%
df["arr_delay"].fillna(0, inplace=True)

# %%
df["dep_delay"].fillna(0, inplace=True)

# %%
df = df.dropna(subset=["air_time"])

# %% [markdown]
# ### Create the columns 'year', 'month', 'day' separating the 'fl_date' column and after that conert it back to a datetime format

# %%
df[["year", "month" ,"day"]] = df["fl_date"].str.split("-", expand = True)

# %%
df1 = df.pop('year')
df2 = df.pop('month')
df3 = df.pop('day')
df.insert(1, "year", df1)
df.insert(2, "month", df2)
df.insert(3, "day", df3)

# %%
df['date'] = pd.to_datetime(df[['year','month', 'day']])

# %%
df4 = df.pop('date')

# %%
df.insert(1, "date", df4)

# %%
df = df.drop(['fl_date'], axis=1)

# %%
df
# Out:
#              date  year month day mkt_unique_carrier branded_code_share  \
# 2      2018-03-07  2018    03  07                 AA                 AA
# 4      2018-03-07  2018    03  07                 AA                 AA
# 5      2018-03-07  2018    03  07                 AA                 AA
# 6      2018-03-07  2018    03  07                 AA                 AA
# 7      2018-03-07  2018    03  07                 AA                 AA
# ...           ...   ...   ...  ..                ...                ...
# 397918 2018-03-07  2018    03  07                 UA       UA_CODESHARE
# 397919 2018-03-07  2018    03  07                 UA       UA_CODESHARE
# 397921 2018-03-07  2018    03  07                 AA       AA_CODESHARE
# 397922 2018-03-07  2018    03  07                 AA       AA_CODESHARE
# 397923 2018-03-07  2018    03  07                 AA                 AA
#
#        mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 2               AA                 465                AA   N200UU
# 4               AA                 591                AA   N833AW
# 5               AA                 600                AA   N151UW
# 6               AA                1805                AA   N924US
# 7               AA                2615                AA   N945NN
# ...            ...                 ...               ...      ...
# 397918          UA                6189                YV   N511MJ
# 397919          UA                6215                YV   N88335
# 397921          AA                4640                YX   N417YX
# 397922          AA                4734                YX   N433YX
# 397923          AA                 179                AA   N105NN
#
#         op_carrier_fl_num  origin_airport_id origin     origin_city_name  \
# 2                     465              14107    PHX          Phoenix, AZ
# 4                     591              11057    CLT        Charlotte, NC
# 5                     600              11697    FLL  Fort Lauderdale, FL
# 6                    1805              11057    CLT        Charlotte, NC
# 7                    2615              11057    CLT        Charlotte, NC
# ...                   ...                ...    ...                  ...
# 397918               6189              11193    CVG       Cincinnati, OH
# 397919               6215              14570    RNO             Reno, NV
# 397921               4640              13303    MIA            Miami, FL
# 397922               4734              14122    PIT       Pittsburgh, PA
# 397923                179              12478    JFK         New York, NY
#
#         dest_airport_id dest     dest_city_name  crs_dep_time  dep_time  \
# 2                 14679  SAN      San Diego, CA           835     833.0
# 4                 11278  DCA     Washington, DC          1431    1537.0
# 5                 11057  CLT      Charlotte, NC           603     557.0
# 6                 10721  BOS         Boston, MA          1135    1129.0
# 7                 15370  TUL          Tulsa, OK          1820    1812.0
# ...                 ...  ...                ...           ...       ...
# 397918            12264  IAD     Washington, DC          1450    1445.0
# 397919            12266  IAH        Houston, TX          1245    1256.0
# 397921            10397  ATL        Atlanta, GA          1607    1555.0
# 397922            13303  MIA          Miami, FL          1900    1855.0
# 397923            14771  SFO  San Francisco, CA          1100    1115.0
#
#         dep_delay  taxi_out  wheels_off  wheels_on  taxi_in  crs_arr_time  \
# 2            -2.0      13.0       846.0      838.0      2.0           851
# 4            66.0      16.0      1553.0     1648.0      3.0          1559
# 5            -6.0      18.0       615.0      746.0     19.0           809
# 6            -6.0      11.0      1140.0     1312.0     12.0          1352
# 7            -8.0      11.0      1823.0     1936.0      6.0          2002
# ...           ...       ...         ...        ...      ...           ...
# 397918       -5.0      16.0      1501.0     1602.0      6.0          1617
# 397919       11.0      13.0      1309.0     1817.0     16.0          1825
# 397921      -12.0      16.0      1611.0     1744.0     11.0          1815
# 397922       -5.0      12.0      1907.0     2128.0      9.0          2154
# 397923       15.0      20.0      1135.0     1426.0      5.0          1448
#
#         arr_time  arr_delay  cancelled cancellation_code  diverted dup  \
# 2          840.0      -11.0        0.0               NaN       0.0   N
# 4         1651.0       52.0        0.0               NaN       0.0   N
# 5          805.0       -4.0        0.0               NaN       0.0   N
# 6         1324.0      -28.0        0.0               NaN       0.0   N
# 7         1942.0      -20.0        0.0               NaN       0.0   N
# ...          ...        ...        ...               ...       ...  ..
# 397918    1608.0       -9.0        0.0               NaN       0.0   N
# 397919    1833.0        8.0        0.0               NaN       0.0   N
# 397921    1755.0      -20.0        0.0               NaN       0.0   N
# 397922    2137.0      -17.0        0.0               NaN       0.0   N
# 397923    1431.0      -17.0        0.0               NaN       0.0   N
#
#         crs_elapsed_time  actual_elapsed_time  air_time  flights  distance  \
# 2                   76.0                 67.0      52.0      1.0     304.0
# 4                   88.0                 74.0      55.0      1.0     331.0
# 5                  126.0                128.0      91.0      1.0     632.0
# 6                  137.0                115.0      92.0      1.0     728.0
# 7                  162.0                150.0     133.0      1.0     842.0
# ...                  ...                  ...       ...      ...       ...
# 397918              87.0                 83.0      61.0      1.0     388.0
# 397919             220.0                217.0     188.0      1.0    1530.0
# 397921             128.0                120.0      93.0      1.0     594.0
# 397922             174.0                162.0     141.0      1.0    1013.0
# 397923             408.0                376.0     351.0      1.0    2586.0
#
#         carrier_delay  weather_delay  nas_delay  security_delay  \
# 2                 NaN            NaN        NaN             NaN
# 4                52.0            0.0        0.0             0.0
# 5                 NaN            NaN        NaN             NaN
# 6                 NaN            NaN        NaN             NaN
# 7                 NaN            NaN        NaN             NaN
# ...               ...            ...        ...             ...
# 397918            NaN            NaN        NaN             NaN
# 397919            NaN            NaN        NaN             NaN
# 397921            NaN            NaN        NaN             NaN
# 397922            NaN            NaN        NaN             NaN
# 397923            NaN            NaN        NaN             NaN
#
#         late_aircraft_delay  first_dep_time  total_add_gtime  \
# 2                       NaN             NaN              NaN
# 4                       0.0             NaN              NaN
# 5                       NaN             NaN              NaN
# 6                       NaN             NaN              NaN
# 7                       NaN             NaN              NaN
# ...                     ...             ...              ...
# 397918                  NaN             NaN              NaN
# 397919                  NaN             NaN              NaN
# 397921                  NaN             NaN              NaN
# 397922                  NaN             NaN              NaN
# 397923                  NaN             NaN              NaN
#
#         longest_add_gtime  no_name
# 2                     NaN      NaN
# 4                     NaN      NaN
# 5                     NaN      NaN
# 6                     NaN      NaN
# 7                     NaN      NaN
# ...                   ...      ...
# 397918                NaN      NaN
# 397919                NaN      NaN
# 397921                NaN      NaN
# 397922                NaN      NaN
# 397923                NaN      NaN
#
# [390060 rows x 45 columns]

# %% [markdown]
# ### Now we check for all missing values and NaN values on the entire data set

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df

# %% [markdown]
# ### Drop the columns with delay values wich we are not supposed to use and also other columns with not usefull information

# %%
df2 = df.drop(['cancellation_code', 'carrier_delay', 'weather_delay', 'nas_delay', 
          'security_delay', 'late_aircraft_delay', 'first_dep_time', 'total_add_gtime', 'longest_add_gtime', 'no_name'], axis=1)

# %% [markdown]
# ### Here we fill the missing values and NaN values with '0' and afterd that set an option for the notebook to show all the columns

# %%
df3 = df2.fillna(0)

# %%
pd.set_option('max_columns', None)

# %% [markdown]
# ### Whe check for null values again and make sure we dont have any more

# %%
percent_missing = df3.isnull().sum() * 100 / len(df3)
missing_value_df = pd.DataFrame({'column_name': df3.columns,
                                 'percent_missing': percent_missing})
missing_value_df

# %% [markdown]
# ### Here we drop more columns and here are the reasons for each:

# %% [markdown]
# - origin - info available in origin_airport_id
# - origin_city_name - info available in origin_airport_id
# - dest - info available in dest_airport_id
# - dest_city_name - info available in dest_airport_id
# - tail_num - all unique ID
# - mkt_carrier_fl_num - all unique ID
# - op_carrier_fl_num - all unique ID
# - flights - just "1" values in all rows
# - dup - just "N" values in all rows
# - mkt_carrier - same info in mkt_unique_carrier

# %%
df4 = df3.drop(['origin', 'origin_city_name', 'dest', 'dest_city_name', 'tail_num', 
                'op_carrier_fl_num', 'flights', 'dup', 'mkt_carrier', 'mkt_unique_carrier', 'mkt_carrier', 
               'branded_code_share', 'cancelled', 'diverted'], axis=1)

# %% [markdown]
# ### Create a copy for data integrity

# %%
df5 = df4.copy()
df5

# %% [markdown]
# ### Now we build a new variable (column 'delayed') indicating whether or not flights are delayed and use it to filter and count the number o delays per each carrier

# %%
df5['delayed'] = df5['arr_delay'].apply(lambda x: x > 0)

# %%
delayed_flights = df5[df5['delayed'] == True] #filter to only rows where delayer == True
delayed_flights['op_unique_carrier'].value_counts() #count the number of rows for each carrier

# %% [markdown]
# ### Now we calculate the proportion of flights that were delayed

# %%
df5.groupby(['op_unique_carrier','delayed']).size().unstack()

# %% [markdown]
# ### Here we assign the values to a new data frame "delayed_by_carrier" and add a new 'clean' index

# %%
delayed_by_carrier = df5.groupby(['op_unique_carrier','delayed']).size().unstack().reset_index()
delayed_by_carrier[:5]

# %% [markdown]
# ### Calculate a new variable "flights_count" with the total delayed and not delayed flights

# %%
delayed_by_carrier['flights_count'] = (delayed_by_carrier[False] + delayed_by_carrier[True])
delayed_by_carrier[:5]

# %% [markdown]
# ### And now we calculate the percentage of flights delayed per each carrier and sort it by 'percentage_delayed'

# %%
delayed_by_carrier['percentage_delayed'] = (delayed_by_carrier[True] / delayed_by_carrier['flights_count'])*100
delayed_by_carrier.sort_values('percentage_delayed', ascending=False)

# %% [markdown]
# ### One option to check the mean (general idea of how many minutes flights were delayed for each airline) its to use a pivot table with the carrier and the delay. It returns the mean of the delay for each carrier

# %%
df5.pivot_table(columns='op_unique_carrier', values='arr_delay', aggfunc=np.mean)

# %% [markdown]
# ### Another option to check the general stats per carrier is use the .describe() function with each carrier. In this case we check for 'WN'

# %%
carrier_delay_stats = df5[df5['op_unique_carrier'] == 'WN']['arr_delay']

# %%
carrier_delay_stats.describe()

# %% [markdown]
# ### Plot an histogram for the delay distribution of each carrier. We start for creating the bins for the X intervals. We use a 10 minutes interval (step=10), starting with 100 minutes early (start=-100) and ending at 200 minutes late (stop=200)

# %%
bin_values = np.arange(start=-100, stop=200, step=5)
bin_values

# %% [markdown]
# ### Here is the histogram for WN carrier

# %%
wn_carrier = df5[df5['op_unique_carrier'] == 'WN']
wn_carrier['arr_delay'].hist(bins=bin_values, figsize=[14,6])

# %%
# y = pd.get_dummies(df5.op_unique_carrier, prefix='carrier')
# y

# %%
df5

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df5[['year','month','day','distance','air_time', 'origin_airport_id', 'dest_airport_id', 
         'taxi_out', 'taxi_in', 'crs_elapsed_time', 'actual_elapsed_time']]

# %%
y = df5['arr_delay']

# %%
scaler = StandardScaler()

# %%
data_scaled = scaler.fit_transform(X)

# %%
reg = LinearRegression().fit(data_scaled, y)

# %%
reg.score(data_scaled, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_scaled, y, test_size=0.30, random_state=1234)

# %%
y_pred = reg.predict(X_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
