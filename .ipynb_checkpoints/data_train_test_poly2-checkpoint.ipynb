# %%
# import pandas
import numpy as np
import pandas as pd
from sklearn import svm
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import auc
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
from sklearn.pipeline import make_pipeline
# %matplotlib inline

pd.set_option('max_columns', None)

# %%
df = pd.read_csv("./data/flights_random_sample_400000.csv")

# %%
df
# Out:
#            fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0       2018-03-07                 AA                 AA          AA
# 1       2018-03-07                 AA                 AA          AA
# 2       2018-03-07                 AA                 AA          AA
# 3       2018-03-07                 AA                 AA          AA
# 4       2018-03-07                 AA                 AA          AA
# ...            ...                ...                ...         ...
# 397919  2018-03-07                 UA       UA_CODESHARE          UA
# 397920  2018-03-07                 AA       AA_CODESHARE          AA
# 397921  2018-03-07                 AA       AA_CODESHARE          AA
# 397922  2018-03-07                 AA       AA_CODESHARE          AA
# 397923  2018-03-07                 AA                 AA          AA
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                      311                AA   N906NN                311
# 1                      332                AA   N946NN                332
# 2                      465                AA   N200UU                465
# 3                      550                AA   N947UW                550
# 4                      591                AA   N833AW                591
# ...                    ...               ...      ...                ...
# 397919                6215                YV   N88335               6215
# 397920                4441                YX      NaN               4441
# 397921                4640                YX   N417YX               4640
# 397922                4734                YX   N433YX               4734
# 397923                 179                AA   N105NN                179
#
#         origin_airport_id origin  origin_city_name  dest_airport_id dest  \
# 0                   13303    MIA         Miami, FL            10529  BDL
# 1                   12953    LGA      New York, NY            13930  ORD
# 2                   14107    PHX       Phoenix, AZ            14679  SAN
# 3                   14100    PHL  Philadelphia, PA            10529  BDL
# 4                   11057    CLT     Charlotte, NC            11278  DCA
# ...                   ...    ...               ...              ...  ...
# 397919              14570    RNO          Reno, NV            12266  IAH
# 397920              14100    PHL  Philadelphia, PA            11278  DCA
# 397921              13303    MIA         Miami, FL            10397  ATL
# 397922              14122    PIT    Pittsburgh, PA            13303  MIA
# 397923              12478    JFK      New York, NY            14771  SFO
#
#            dest_city_name  crs_dep_time  dep_time  dep_delay  taxi_out  \
# 0            Hartford, CT          1940       NaN        NaN       NaN
# 1             Chicago, IL          1330       NaN        NaN       NaN
# 2           San Diego, CA           835     833.0       -2.0      13.0
# 3            Hartford, CT          2050       NaN        NaN       NaN
# 4          Washington, DC          1431    1537.0       66.0      16.0
# ...                   ...           ...       ...        ...       ...
# 397919        Houston, TX          1245    1256.0       11.0      13.0
# 397920     Washington, DC          2110       NaN        NaN       NaN
# 397921        Atlanta, GA          1607    1555.0      -12.0      16.0
# 397922          Miami, FL          1900    1855.0       -5.0      12.0
# 397923  San Francisco, CA          1100    1115.0       15.0      20.0
#
#         wheels_off  wheels_on  taxi_in  crs_arr_time  arr_time  arr_delay  \
# 0              NaN        NaN      NaN          2249       NaN        NaN
# 1              NaN        NaN      NaN          1512       NaN        NaN
# 2            846.0      838.0      2.0           851     840.0      -11.0
# 3              NaN        NaN      NaN          2156       NaN        NaN
# 4           1553.0     1648.0      3.0          1559    1651.0       52.0
# ...            ...        ...      ...           ...       ...        ...
# 397919      1309.0     1817.0     16.0          1825    1833.0        8.0
# 397920         NaN        NaN      NaN          2218       NaN        NaN
# 397921      1611.0     1744.0     11.0          1815    1755.0      -20.0
# 397922      1907.0     2128.0      9.0          2154    2137.0      -17.0
# 397923      1135.0     1426.0      5.0          1448    1431.0      -17.0
#
#         cancelled cancellation_code  diverted dup  crs_elapsed_time  \
# 0             1.0                 B       0.0   N             189.0
# 1             1.0                 B       0.0   N             162.0
# 2             0.0               NaN       0.0   N              76.0
# 3             1.0                 B       0.0   N              66.0
# 4             0.0               NaN       0.0   N              88.0
# ...           ...               ...       ...  ..               ...
# 397919        0.0               NaN       0.0   N             220.0
# 397920        1.0                 B       0.0   N              68.0
# 397921        0.0               NaN       0.0   N             128.0
# 397922        0.0               NaN       0.0   N             174.0
# 397923        0.0               NaN       0.0   N             408.0
#
#         actual_elapsed_time  air_time  flights  distance  carrier_delay  \
# 0                       NaN       NaN      1.0    1194.0            NaN
# 1                       NaN       NaN      1.0     733.0            NaN
# 2                      67.0      52.0      1.0     304.0            NaN
# 3                       NaN       NaN      1.0     196.0            NaN
# 4                      74.0      55.0      1.0     331.0           52.0
# ...                     ...       ...      ...       ...            ...
# 397919                217.0     188.0      1.0    1530.0            NaN
# 397920                  NaN       NaN      1.0     119.0            NaN
# 397921                120.0      93.0      1.0     594.0            NaN
# 397922                162.0     141.0      1.0    1013.0            NaN
# 397923                376.0     351.0      1.0    2586.0            NaN
#
#         weather_delay  nas_delay  security_delay  late_aircraft_delay  \
# 0                 NaN        NaN             NaN                  NaN
# 1                 NaN        NaN             NaN                  NaN
# 2                 NaN        NaN             NaN                  NaN
# 3                 NaN        NaN             NaN                  NaN
# 4                 0.0        0.0             0.0                  0.0
# ...               ...        ...             ...                  ...
# 397919            NaN        NaN             NaN                  NaN
# 397920            NaN        NaN             NaN                  NaN
# 397921            NaN        NaN             NaN                  NaN
# 397922            NaN        NaN             NaN                  NaN
# 397923            NaN        NaN             NaN                  NaN
#
#         first_dep_time  total_add_gtime  longest_add_gtime  no_name
# 0                  NaN              NaN                NaN      NaN
# 1                  NaN              NaN                NaN      NaN
# 2                  NaN              NaN                NaN      NaN
# 3                  NaN              NaN                NaN      NaN
# 4                  NaN              NaN                NaN      NaN
# ...                ...              ...                ...      ...
# 397919             NaN              NaN                NaN      NaN
# 397920             NaN              NaN                NaN      NaN
# 397921             NaN              NaN                NaN      NaN
# 397922             NaN              NaN                NaN      NaN
# 397923             NaN              NaN                NaN      NaN
#
# [397924 rows x 42 columns]

# %% [markdown]
# ### Create the columns 'year', 'month', 'day' separating the 'fl_date' column and after that conert it back to a datetime format

# %%
df[["year", "month" ,"day"]] = df["fl_date"].str.split("-", expand = True)

# %%
df1 = df.pop('year')
df2 = df.pop('month')
df3 = df.pop('day')
df.insert(1, "year", df1)
df.insert(2, "month", df2)
df.insert(3, "day", df3)

# %%
df['date'] = pd.to_datetime(df[['year','month', 'day']])
df.drop(['fl_date'], axis=1)
# Out:
#         year month day mkt_unique_carrier branded_code_share mkt_carrier  \
# 0       2018    03  07                 AA                 AA          AA
# 1       2018    03  07                 AA                 AA          AA
# 2       2018    03  07                 AA                 AA          AA
# 3       2018    03  07                 AA                 AA          AA
# 4       2018    03  07                 AA                 AA          AA
# ...      ...   ...  ..                ...                ...         ...
# 397919  2018    03  07                 UA       UA_CODESHARE          UA
# 397920  2018    03  07                 AA       AA_CODESHARE          AA
# 397921  2018    03  07                 AA       AA_CODESHARE          AA
# 397922  2018    03  07                 AA       AA_CODESHARE          AA
# 397923  2018    03  07                 AA                 AA          AA
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# 0                      311                AA   N906NN                311
# 1                      332                AA   N946NN                332
# 2                      465                AA   N200UU                465
# 3                      550                AA   N947UW                550
# 4                      591                AA   N833AW                591
# ...                    ...               ...      ...                ...
# 397919                6215                YV   N88335               6215
# 397920                4441                YX      NaN               4441
# 397921                4640                YX   N417YX               4640
# 397922                4734                YX   N433YX               4734
# 397923                 179                AA   N105NN                179
#
#         origin_airport_id origin  origin_city_name  dest_airport_id dest  \
# 0                   13303    MIA         Miami, FL            10529  BDL
# 1                   12953    LGA      New York, NY            13930  ORD
# 2                   14107    PHX       Phoenix, AZ            14679  SAN
# 3                   14100    PHL  Philadelphia, PA            10529  BDL
# 4                   11057    CLT     Charlotte, NC            11278  DCA
# ...                   ...    ...               ...              ...  ...
# 397919              14570    RNO          Reno, NV            12266  IAH
# 397920              14100    PHL  Philadelphia, PA            11278  DCA
# 397921              13303    MIA         Miami, FL            10397  ATL
# 397922              14122    PIT    Pittsburgh, PA            13303  MIA
# 397923              12478    JFK      New York, NY            14771  SFO
#
#            dest_city_name  crs_dep_time  dep_time  dep_delay  taxi_out  \
# 0            Hartford, CT          1940       NaN        NaN       NaN
# 1             Chicago, IL          1330       NaN        NaN       NaN
# 2           San Diego, CA           835     833.0       -2.0      13.0
# 3            Hartford, CT          2050       NaN        NaN       NaN
# 4          Washington, DC          1431    1537.0       66.0      16.0
# ...                   ...           ...       ...        ...       ...
# 397919        Houston, TX          1245    1256.0       11.0      13.0
# 397920     Washington, DC          2110       NaN        NaN       NaN
# 397921        Atlanta, GA          1607    1555.0      -12.0      16.0
# 397922          Miami, FL          1900    1855.0       -5.0      12.0
# 397923  San Francisco, CA          1100    1115.0       15.0      20.0
#
#         wheels_off  wheels_on  taxi_in  crs_arr_time  arr_time  arr_delay  \
# 0              NaN        NaN      NaN          2249       NaN        NaN
# 1              NaN        NaN      NaN          1512       NaN        NaN
# 2            846.0      838.0      2.0           851     840.0      -11.0
# 3              NaN        NaN      NaN          2156       NaN        NaN
# 4           1553.0     1648.0      3.0          1559    1651.0       52.0
# ...            ...        ...      ...           ...       ...        ...
# 397919      1309.0     1817.0     16.0          1825    1833.0        8.0
# 397920         NaN        NaN      NaN          2218       NaN        NaN
# 397921      1611.0     1744.0     11.0          1815    1755.0      -20.0
# 397922      1907.0     2128.0      9.0          2154    2137.0      -17.0
# 397923      1135.0     1426.0      5.0          1448    1431.0      -17.0
#
#         cancelled cancellation_code  diverted dup  crs_elapsed_time  \
# 0             1.0                 B       0.0   N             189.0
# 1             1.0                 B       0.0   N             162.0
# 2             0.0               NaN       0.0   N              76.0
# 3             1.0                 B       0.0   N              66.0
# 4             0.0               NaN       0.0   N              88.0
# ...           ...               ...       ...  ..               ...
# 397919        0.0               NaN       0.0   N             220.0
# 397920        1.0                 B       0.0   N              68.0
# 397921        0.0               NaN       0.0   N             128.0
# 397922        0.0               NaN       0.0   N             174.0
# 397923        0.0               NaN       0.0   N             408.0
#
#         actual_elapsed_time  air_time  flights  distance  carrier_delay  \
# 0                       NaN       NaN      1.0    1194.0            NaN
# 1                       NaN       NaN      1.0     733.0            NaN
# 2                      67.0      52.0      1.0     304.0            NaN
# 3                       NaN       NaN      1.0     196.0            NaN
# 4                      74.0      55.0      1.0     331.0           52.0
# ...                     ...       ...      ...       ...            ...
# 397919                217.0     188.0      1.0    1530.0            NaN
# 397920                  NaN       NaN      1.0     119.0            NaN
# 397921                120.0      93.0      1.0     594.0            NaN
# 397922                162.0     141.0      1.0    1013.0            NaN
# 397923                376.0     351.0      1.0    2586.0            NaN
#
#         weather_delay  nas_delay  security_delay  late_aircraft_delay  \
# 0                 NaN        NaN             NaN                  NaN
# 1                 NaN        NaN             NaN                  NaN
# 2                 NaN        NaN             NaN                  NaN
# 3                 NaN        NaN             NaN                  NaN
# 4                 0.0        0.0             0.0                  0.0
# ...               ...        ...             ...                  ...
# 397919            NaN        NaN             NaN                  NaN
# 397920            NaN        NaN             NaN                  NaN
# 397921            NaN        NaN             NaN                  NaN
# 397922            NaN        NaN             NaN                  NaN
# 397923            NaN        NaN             NaN                  NaN
#
#         first_dep_time  total_add_gtime  longest_add_gtime  no_name       date
# 0                  NaN              NaN                NaN      NaN 2018-03-07
# 1                  NaN              NaN                NaN      NaN 2018-03-07
# 2                  NaN              NaN                NaN      NaN 2018-03-07
# 3                  NaN              NaN                NaN      NaN 2018-03-07
# 4                  NaN              NaN                NaN      NaN 2018-03-07
# ...                ...              ...                ...      ...        ...
# 397919             NaN              NaN                NaN      NaN 2018-03-07
# 397920             NaN              NaN                NaN      NaN 2018-03-07
# 397921             NaN              NaN                NaN      NaN 2018-03-07
# 397922             NaN              NaN                NaN      NaN 2018-03-07
# 397923             NaN              NaN                NaN      NaN 2018-03-07
#
# [397924 rows x 45 columns]

# %%
import datetime

# Function that convert the 'HHMM' string to datetime.time "1940 -> 19:40:00"
def time_format(chain):
    if pd.isnull(chain):
        return np.nan
    else:
        if chain == 2400: chain = 0
        chain = "{0:04d}".format(int(chain))
        time = datetime.time(int(chain[0:2]), int(chain[2:4]))
        return time

# %%
df['crs_dep_time'] = df['crs_dep_time'].apply(time_format)

# %%
df['dep_time'] = df['dep_time'].apply(time_format)

# %%
df['crs_arr_time'] = df['crs_arr_time'].apply(time_format)

# %%
df['arr_time'] = df['arr_time'].apply(time_format)

# %%
variables_to_remove = ['taxi_out', 'taxi_in', 'wheels_on', 'wheels_off', 'year','month','day','date', 'nas_delay', 'security_delay', 'carrier_delay', 'late_aircraft_delay',
                       'weather_delay', 'diverted', 'cancelled', 'cancellation_code','mkt_carrier_fl_num', 'tail_num', 'air_time', 'mkt_unique_carrier', 'branded_code_share', 
                       'mkt_carrier', 'op_carrier_fl_num', 'dup', 'flights', 'first_dep_time', 'total_add_gtime', 'longest_add_gtime', 'no_name']

# %%
df.drop(variables_to_remove, axis = 1, inplace = True)

# %%
df = df[['op_unique_carrier', 'origin_city_name', 'origin', 'origin_airport_id', 'dest_city_name', 'dest', 'dest_airport_id', 'crs_dep_time', 'dep_time', 'dep_delay', 'crs_arr_time', 'arr_time', 'arr_delay', 'crs_elapsed_time', 'actual_elapsed_time']]

# %%
df
# Out:
#        op_unique_carrier  origin_city_name origin  origin_airport_id  \
# 0                     AA         Miami, FL    MIA              13303
# 1                     AA      New York, NY    LGA              12953
# 2                     AA       Phoenix, AZ    PHX              14107
# 3                     AA  Philadelphia, PA    PHL              14100
# 4                     AA     Charlotte, NC    CLT              11057
# ...                  ...               ...    ...                ...
# 397919                YV          Reno, NV    RNO              14570
# 397920                YX  Philadelphia, PA    PHL              14100
# 397921                YX         Miami, FL    MIA              13303
# 397922                YX    Pittsburgh, PA    PIT              14122
# 397923                AA      New York, NY    JFK              12478
#
#            dest_city_name dest  dest_airport_id crs_dep_time  dep_time  \
# 0            Hartford, CT  BDL            10529     19:40:00       NaN
# 1             Chicago, IL  ORD            13930     13:30:00       NaN
# 2           San Diego, CA  SAN            14679     08:35:00  08:33:00
# 3            Hartford, CT  BDL            10529     20:50:00       NaN
# 4          Washington, DC  DCA            11278     14:31:00  15:37:00
# ...                   ...  ...              ...          ...       ...
# 397919        Houston, TX  IAH            12266     12:45:00  12:56:00
# 397920     Washington, DC  DCA            11278     21:10:00       NaN
# 397921        Atlanta, GA  ATL            10397     16:07:00  15:55:00
# 397922          Miami, FL  MIA            13303     19:00:00  18:55:00
# 397923  San Francisco, CA  SFO            14771     11:00:00  11:15:00
#
#         dep_delay crs_arr_time  arr_time  arr_delay  crs_elapsed_time  \
# 0             NaN     22:49:00       NaN        NaN             189.0
# 1             NaN     15:12:00       NaN        NaN             162.0
# 2            -2.0     08:51:00  08:40:00      -11.0              76.0
# 3             NaN     21:56:00       NaN        NaN              66.0
# 4            66.0     15:59:00  16:51:00       52.0              88.0
# ...           ...          ...       ...        ...               ...
# 397919       11.0     18:25:00  18:33:00        8.0             220.0
# 397920        NaN     22:18:00       NaN        NaN              68.0
# 397921      -12.0     18:15:00  17:55:00      -20.0             128.0
# 397922       -5.0     21:54:00  21:37:00      -17.0             174.0
# 397923       15.0     14:48:00  14:31:00      -17.0             408.0
#
#         actual_elapsed_time
# 0                       NaN
# 1                       NaN
# 2                      67.0
# 3                       NaN
# 4                      74.0
# ...                     ...
# 397919                217.0
# 397920                  NaN
# 397921                120.0
# 397922                162.0
# 397923                376.0
#
# [397924 rows x 15 columns]

# %%
df.dropna(inplace = True)
# Out:
# <ipython-input-16-d1ada024d2eb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace = True)

# %%
missing_df = df.isnull().sum(axis=0).reset_index()
missing_df.columns = ['variable', 'missing values']
missing_df['filling factor (%)']=(df.shape[0]-missing_df['missing values'])/df.shape[0]*100
missing_df.sort_values('filling factor (%)').reset_index(drop = True)
# Out:
#                variable  missing values  filling factor (%)
# 0     op_unique_carrier               0               100.0
# 1      origin_city_name               0               100.0
# 2                origin               0               100.0
# 3     origin_airport_id               0               100.0
# 4        dest_city_name               0               100.0
# 5                  dest               0               100.0
# 6       dest_airport_id               0               100.0
# 7          crs_dep_time               0               100.0
# 8              dep_time               0               100.0
# 9             dep_delay               0               100.0
# 10         crs_arr_time               0               100.0
# 11             arr_time               0               100.0
# 12            arr_delay               0               100.0
# 13     crs_elapsed_time               0               100.0
# 14  actual_elapsed_time               0               100.0

# %%
# #__________________________________________________________________
# # function that extract statistical parameters from a grouby objet:
# def get_stats(group):
#     return {'min': group.min(), 'max': group.max(),
#             'count': group.count(), 'mean': group.mean()}
# #_______________________________________________________________
# # Creation of a dataframe with statitical infos on each airline:
# global_stats = df['dep_delay'].groupby(df['op_unique_carrier']).apply(get_stats).unstack()
# global_stats = global_stats.sort_values('count')
# global_stats

# %%
df2 = df.copy()

# %%
df2
# Out:
#        op_unique_carrier     origin_city_name origin  origin_airport_id  \
# 2                     AA          Phoenix, AZ    PHX              14107
# 4                     AA        Charlotte, NC    CLT              11057
# 5                     AA  Fort Lauderdale, FL    FLL              11697
# 6                     AA        Charlotte, NC    CLT              11057
# 7                     AA        Charlotte, NC    CLT              11057
# ...                  ...                  ...    ...                ...
# 397918                YV       Cincinnati, OH    CVG              11193
# 397919                YV             Reno, NV    RNO              14570
# 397921                YX            Miami, FL    MIA              13303
# 397922                YX       Pittsburgh, PA    PIT              14122
# 397923                AA         New York, NY    JFK              12478
#
#            dest_city_name dest  dest_airport_id crs_dep_time  dep_time  \
# 2           San Diego, CA  SAN            14679     08:35:00  08:33:00
# 4          Washington, DC  DCA            11278     14:31:00  15:37:00
# 5           Charlotte, NC  CLT            11057     06:03:00  05:57:00
# 6              Boston, MA  BOS            10721     11:35:00  11:29:00
# 7               Tulsa, OK  TUL            15370     18:20:00  18:12:00
# ...                   ...  ...              ...          ...       ...
# 397918     Washington, DC  IAD            12264     14:50:00  14:45:00
# 397919        Houston, TX  IAH            12266     12:45:00  12:56:00
# 397921        Atlanta, GA  ATL            10397     16:07:00  15:55:00
# 397922          Miami, FL  MIA            13303     19:00:00  18:55:00
# 397923  San Francisco, CA  SFO            14771     11:00:00  11:15:00
#
#         dep_delay crs_arr_time  arr_time  arr_delay  crs_elapsed_time  \
# 2            -2.0     08:51:00  08:40:00      -11.0              76.0
# 4            66.0     15:59:00  16:51:00       52.0              88.0
# 5            -6.0     08:09:00  08:05:00       -4.0             126.0
# 6            -6.0     13:52:00  13:24:00      -28.0             137.0
# 7            -8.0     20:02:00  19:42:00      -20.0             162.0
# ...           ...          ...       ...        ...               ...
# 397918       -5.0     16:17:00  16:08:00       -9.0              87.0
# 397919       11.0     18:25:00  18:33:00        8.0             220.0
# 397921      -12.0     18:15:00  17:55:00      -20.0             128.0
# 397922       -5.0     21:54:00  21:37:00      -17.0             174.0
# 397923       15.0     14:48:00  14:31:00      -17.0             408.0
#
#         actual_elapsed_time
# 2                      67.0
# 4                      74.0
# 5                     128.0
# 6                     115.0
# 7                     150.0
# ...                     ...
# 397918                 83.0
# 397919                217.0
# 397921                120.0
# 397922                162.0
# 397923                376.0
#
# [390046 rows x 15 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
# convert from hour to minutes
fct = lambda x:x.hour*60+x.minute

# %%
df2['dep_time_min'] = df2['dep_time'].apply(fct)

# %%
df2['crs_dep_time_min'] = df2['crs_dep_time'].apply(fct)

# %%
df2
# Out:
#        op_unique_carrier     origin_city_name origin  origin_airport_id  \
# 2                     AA          Phoenix, AZ    PHX              14107
# 4                     AA        Charlotte, NC    CLT              11057
# 5                     AA  Fort Lauderdale, FL    FLL              11697
# 6                     AA        Charlotte, NC    CLT              11057
# 7                     AA        Charlotte, NC    CLT              11057
# ...                  ...                  ...    ...                ...
# 397918                YV       Cincinnati, OH    CVG              11193
# 397919                YV             Reno, NV    RNO              14570
# 397921                YX            Miami, FL    MIA              13303
# 397922                YX       Pittsburgh, PA    PIT              14122
# 397923                AA         New York, NY    JFK              12478
#
#            dest_city_name dest  dest_airport_id crs_dep_time  dep_time  \
# 2           San Diego, CA  SAN            14679     08:35:00  08:33:00
# 4          Washington, DC  DCA            11278     14:31:00  15:37:00
# 5           Charlotte, NC  CLT            11057     06:03:00  05:57:00
# 6              Boston, MA  BOS            10721     11:35:00  11:29:00
# 7               Tulsa, OK  TUL            15370     18:20:00  18:12:00
# ...                   ...  ...              ...          ...       ...
# 397918     Washington, DC  IAD            12264     14:50:00  14:45:00
# 397919        Houston, TX  IAH            12266     12:45:00  12:56:00
# 397921        Atlanta, GA  ATL            10397     16:07:00  15:55:00
# 397922          Miami, FL  MIA            13303     19:00:00  18:55:00
# 397923  San Francisco, CA  SFO            14771     11:00:00  11:15:00
#
#         dep_delay crs_arr_time  arr_time  arr_delay  crs_elapsed_time  \
# 2            -2.0     08:51:00  08:40:00      -11.0              76.0
# 4            66.0     15:59:00  16:51:00       52.0              88.0
# 5            -6.0     08:09:00  08:05:00       -4.0             126.0
# 6            -6.0     13:52:00  13:24:00      -28.0             137.0
# 7            -8.0     20:02:00  19:42:00      -20.0             162.0
# ...           ...          ...       ...        ...               ...
# 397918       -5.0     16:17:00  16:08:00       -9.0              87.0
# 397919       11.0     18:25:00  18:33:00        8.0             220.0
# 397921      -12.0     18:15:00  17:55:00      -20.0             128.0
# 397922       -5.0     21:54:00  21:37:00      -17.0             174.0
# 397923       15.0     14:48:00  14:31:00      -17.0             408.0
#
#         actual_elapsed_time  dep_time_min  crs_dep_time_min
# 2                      67.0           513               515
# 4                      74.0           937               871
# 5                     128.0           357               363
# 6                     115.0           689               695
# 7                     150.0          1092              1100
# ...                     ...           ...               ...
# 397918                 83.0           885               890
# 397919                217.0           776               765
# 397921                120.0           955               967
# 397922                162.0          1135              1140
# 397923                376.0           675               660
#
# [390046 rows x 17 columns]

# %%
#----------------------------------
#Test
from sklearn.preprocessing import PolynomialFeatures

X = df2[['crs_dep_time_min','dep_time_min','origin_airport_id','dest_airport_id']]
y = df2['arr_delay']


poly = PolynomialFeatures(2)

# %%
X, y
# Out:
# (        crs_dep_time_min  dep_time_min  origin_airport_id  dest_airport_id
#  2                    515           513              14107            14679
#  4                    871           937              11057            11278
#  5                    363           357              11697            11057
#  6                    695           689              11057            10721
#  7                   1100          1092              11057            15370
#  ...                  ...           ...                ...              ...
#  397918               890           885              11193            12264
#  397919               765           776              14570            12266
#  397921               967           955              13303            10397
#  397922              1140          1135              14122            13303
#  397923               660           675              12478            14771
#
#  [390046 rows x 4 columns],
#  2        -11.0
#  4         52.0
#  5         -4.0
#  6        -28.0
#  7        -20.0
#            ...
#  397918    -9.0
#  397919     8.0
#  397921   -20.0
#  397922   -17.0
#  397923   -17.0
#  Name: arr_delay, Length: 390046, dtype: float64)

# %%
#----------------------------------
#Test
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
y_scaled = scaler.fit_transform(y.values.reshape(-1,1))

# %%
#----------------------------------
#Test
Xt = poly.fit_transform(X_scaled)
X_test, X_train, y_test, y_train = train_test_split(Xt,y_scaled, train_size=0.8, random_state=1234)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
r2_train = model.score(X_train, y_train)
r2_test = model.score(X_test, y_test)

print("---Results---")
print(f"degree = {2}")
print(f"Train score = {r2_train}")
print(f"Test score = {r2_test}")
# Out:
# ---Results---
# degree = 2
# Train score = 0.4386242385314898
# Test score = 0.3900732374671444

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.27246059815370344
# Mean Squared Error: 0.6129440704600682
# Root Mean Squared Error: 0.782907446931033
